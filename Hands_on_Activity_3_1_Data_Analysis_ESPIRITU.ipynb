# %% [markdown]
# #Submission Details
#
# Name: **Diego Angelo G. Espiritu**
#
# Course and Section: **CPE 019 | CPE32S1**
#
# Date of Submission: **6/14/2024**
#
# Instructor: **Engr. Roman Richard**
#
# ---

# %% [markdown]
# # Lab - Correlation Analysis in Python
#
# Objectives:<br>
# * Part 1: The Dataset.<br>
# * Part 2: Scatterplot Graphs and Correlatable Variables.<br>
# * Part 3: Calculating Correlation with Python.<br>
# * Part 4: Visualizing.<br>
#
# ## Scenario/Background
# * Correlation is an important statistical relationship that can indicate whether the variable values are linearly related.<br>
# * In this lab, you will learn how to use Python to calculate correlation. In Part 1, you will setup the dataset.
# In Part 2, you will learn how to identify if the variables in a given dataset are correlatable. Finally, in Part
# 3, you will use Python to calculate the correlation between two sets of variable.<br>
#
# ## Required Resources
# * 1 PC with Internet access
# * Raspberry Pi version 2 or higher
# * Python libraries: pandas, numpy, matplotlib, seaborn
# * Datafiles: brainsize.txt

# %% [markdown]
# # Part 1: The Dataset

# %% [markdown]
# Step 1: Loading the Dataset From a File.

# %%
# Code cell 1
import pandas as pd
brainFile = '/content/brainsize.txt'
brainFrame = pd.read_csv(brainFile, delimiter = '\t')

# %% [markdown]
# Step 2: Verifying the dataframe.

# %%
# Code cell 2
brainFrame.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0  Female   133  132  124   118.0    64.5     816932
# 1    Male   140  150  124     NaN    72.5    1001121
# 2    Male   139  123  150   143.0    73.3    1038437
# 3    Male   133  129  128   172.0    68.8     965353
# 4  Female   137  132  134   147.0    65.0     951545

# %% [markdown]
# # Part 2: Scatterplot Graphs and Correlatable Variables

# %% [markdown]
# Step 1: The pandas describe() method

# %%
# Code cell 3
brainFrame.describe()
# Out:
#              FSIQ         VIQ        PIQ      Weight     Height     MRI_Count
# count   40.000000   40.000000   40.00000   38.000000  39.000000  4.000000e+01
# mean   113.450000  112.350000  111.02500  151.052632  68.525641  9.087550e+05
# std     24.082071   23.616107   22.47105   23.478509   3.994649  7.228205e+04
# min     77.000000   71.000000   72.00000  106.000000  62.000000  7.906190e+05
# 25%     89.750000   90.000000   88.25000  135.250000  66.000000  8.559185e+05
# 50%    116.500000  113.000000  115.00000  146.500000  68.000000  9.053990e+05
# 75%    135.500000  129.750000  128.00000  172.000000  70.500000  9.500780e+05
# max    144.000000  150.000000  150.00000  192.000000  77.000000  1.079549e+06

# %% [markdown]
# Step 2: Scatterplot graphs

# %% [markdown]
# a. Load the required modules.
#
# Before graphs can be plotted, it is necessary to import a few modules, namely numpy and matplotlib.
# Run the cell below to load these modules.

# %%
# Code cell 4
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# b. Separate the data.
#
# To ensure the results do not get skewed because of the differences in male and female bodies, the
# dateframe is split into two dataframes: one containing all male entries and another with only female
# instances.
# Running the cell below creates the two new dataframes, menDf and womenDf, each one containing the
# respective entries.

# %%
 # Code cell 5
print(brainFrame.columns)
# Out:
# Index(['Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count'], dtype='object')

# %%
# Code cell 6
menDf = brainFrame[(brainFrame.Gender == 'Male')]
womenDf = brainFrame[(brainFrame.Gender == 'Female')]

# %% [markdown]
# c. Plot the graphs.

# %%
# Code cell 7
menMeanSmarts = menDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(menMeanSmarts, menDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %% [markdown]
# Similarly, the code below creates a scatterplot graph for the women-only filtered dataframe.

# %%
# Code cell 7
# Graph the women-only filtered dataframe
#womenMeanSmarts = ?
#plt.scatter(?, ?)

plt.show()
# %matplotlib inline

# %% [markdown]
# # Part 3: Calculating Correlation with Python

# %%
# Code cell 8
brainFrame.corr(method='pearson')
# Out:
# <ipython-input-73-cab48f3abe05>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   brainFrame.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.946639  0.934125 -0.051483 -0.086002   0.357641
# VIQ        0.946639  1.000000  0.778135 -0.076088 -0.071068   0.337478
# PIQ        0.934125  0.778135  1.000000  0.002512 -0.076723   0.386817
# Weight    -0.051483 -0.076088  0.002512  1.000000  0.699614   0.513378
# Height    -0.086002 -0.071068 -0.076723  0.699614  1.000000   0.601712
# MRI_Count  0.357641  0.337478  0.386817  0.513378  0.601712   1.000000

# %%
# Code cell 9
womenDf.corr(method='pearson')
# Out:
# <ipython-input-74-a6271751808a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   womenDf.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.955717  0.939382  0.038192 -0.059011   0.325697
# VIQ        0.955717  1.000000  0.802652 -0.021889 -0.146453   0.254933
# PIQ        0.939382  0.802652  1.000000  0.113901 -0.001242   0.396157
# Weight     0.038192 -0.021889  0.113901  1.000000  0.552357   0.446271
# Height    -0.059011 -0.146453 -0.001242  0.552357  1.000000   0.174541
# MRI_Count  0.325697  0.254933  0.396157  0.446271  0.174541   1.000000

# %%
# Code cell 10
# Use corr() for the male-only dataframe with the pearson method
#?.corr(?)

# %%
# Code cell 11
# !pip install seaborn

# %%
# Code cell 12
import seaborn as sns
wcorr = womenDf.corr()
sns.heatmap(wcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-77-2465c40f5efb>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   wcorr = womenDf.corr()
# <Axes: >

# %%
# Code cell 13
mcorr = menDf.corr()
sns.heatmap(mcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-78-c0059f16aa63>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mcorr = menDf.corr()
# <Axes: >

# %% [markdown]
# Many variable pairs present correlation close to zero. What does that mean?
#
# - **There will be no relation if the variable pair has a correlation near to zero.**
#
# Why separate the genders?
#
# - **The genders is being compared and seperated in brain size and in the brain activity as  data per gender.**
#
# What variables have stronger correlation with brain size (MRI_Count)? Is that expected? Explain.
#
# - **Given that size and mass are exactly corresponding, it would be the variable "weight." Consequently, a larger brain will undoubtedly weigh more.**

# %% [markdown]
# # Supplmentary Activity

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
covid = '/content/drive/MyDrive/PHCovid_Datasets.csv'
covidData = pd.read_csv(covid)

# %%
covidData.head()
# Out:
#                    Related          Last      Previous             Unit  \
# 0             Covid Deaths  6.645300e+04  6.644400e+04          Persons
# 1              Covid Cases  4.115202e+06  4.102788e+06          Persons
# 2  Covid Vaccination Total  1.706902e+08  1.706384e+08            doses
# 3   Covid Vaccination Rate  1.477100e+02  1.476600e+02  dose/100 people
# 4          Covid Recovered  1.339248e+06  1.333464e+06          Persons
#
#   Reference
# 0   May2023
# 1   May2023
# 2   Mar2023
# 3   Mar2023
# 4  Dec 2021

# %%
covidData.describe()
# Out:
#                Last      Previous
# count  5.000000e+00  5.000000e+00
# mean   3.524225e+07  3.522824e+07
# std    7.573605e+07  7.571480e+07
# min    1.477100e+02  1.476600e+02
# 25%    6.645300e+04  6.644400e+04
# 50%    1.339248e+06  1.333464e+06
# 75%    4.115202e+06  4.102788e+06
# max    1.706902e+08  1.706384e+08

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
deathsDf = covidData[(covidData.Related == 'Covid Deaths')]
casesDf = covidData[(covidData.Related == 'Covid Cases')]
totalDf = covidData[(covidData.Related == 'Covid Vaccination Total')]
rateDf = covidData[(covidData.Related == 'Covid Vaccination Rate')]
recoveredDf = covidData[(covidData.Related == 'Covid Recovered')]

# %%
deaths = deathsDf[["Last", "Previous"]].mean(axis=1)
plt.scatter(deaths, deathsDf["Reference"])
plt.show()
# %matplotlib inline

# %%
covidData.corr(method='pearson')
# Out:
# <ipython-input-62-f73f0cace727>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   covidData.corr(method='pearson')
#           Last  Previous
# Last       1.0       1.0
# Previous   1.0       1.0

# %%
import seaborn as sns
dcorr = deathsDf.corr()
sns.heatmap(dcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-63-1dc4b0e8df4b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dcorr = deathsDf.corr()
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <Axes: >

# %%
ccorr = casesDf.corr()
sns.heatmap(ccorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-64-5bb8137f840b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ccorr = casesDf.corr()
# <Axes: >

# %% [markdown]
# # Conclusion:
#
# Summary:
# * The focus of this hands-on exercise is data analysis, which makes it easier to study and evaluate and explore the data for better understanding.
#
# Conclusion:
# * For this hands on activity we are taught on how to analyze and explore and also clean the datasets that will have a better understanding for the given data.
#
# Lesson Learned:
# * In this hands on activity I learned basic and simple data analysis with the help of google colab, this platform help me to explore and analysze the data for better information and clean them for better understading.
