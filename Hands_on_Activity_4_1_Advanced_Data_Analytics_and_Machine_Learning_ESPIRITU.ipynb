# %% [markdown]
# #Submission Details
#
# Name: **Diego Angelo G. Espiritu**
#
# Course and Section: **CPE 019 | CPE32S1**
#
# Date of Submission: **20/06/2024**
#
# Instructor: **Engr. Roman Richard**
#
# ---

# %% [markdown]
# # **Part 1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Emtech_Drive/titanic_train.csv"
read = pd.read_csv(path)

thap = "/content/drive/MyDrive/Emtech_Drive/titanic_test.csv"
dear = pd.read_csv(thap)

# %%
read["Sex"] = read["Sex"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)
read["Age"].fillna(read["Age"].mean(), inplace=True)

# %%
read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
read.corr()
# Out:
# <ipython-input-11-bc27bf2015f5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   read.corr()
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.042939  0.033207 -0.057527
# Survived       -0.005007  1.000000 -0.338481  0.543351 -0.069809 -0.035322
# Pclass         -0.035144 -0.338481  1.000000 -0.131900 -0.331339  0.083081
# Sex            -0.042939  0.543351 -0.131900  1.000000 -0.084153  0.114631
# Age             0.033207 -0.069809 -0.331339 -0.084153  1.000000 -0.232625
# SibSp          -0.057527 -0.035322  0.083081  0.114631 -0.232625  1.000000
# Parch          -0.001652  0.081629  0.018443  0.245489 -0.179191  0.414838
# Fare            0.012658  0.257307 -0.549500  0.182333  0.091566  0.159651
#
# ...

# %%
read.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.352413   29.699118
# std     257.353842    0.486592    0.836071    0.477990   13.002015
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     223.500000    0.000000    2.000000    0.000000   22.000000
# 50%     446.000000    0.000000    3.000000    0.000000   29.699118
# 75%     668.500000    1.000000    3.000000    1.000000   35.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
read.plot()
# Out:
# <Axes: >

# %%
read.describe().plot()
# Out:
# <Axes: >

# %%
sns.regplot(x="Fare", y="Survived", data=read)
# Out:
# <Axes: xlabel='Fare', ylabel='Survived'>

# %%
sns.regplot(x="Age", y="Survived", data=read)
# Out:
# <Axes: xlabel='Age', ylabel='Survived'>

# %%
dear["Sex"] = dear["Sex"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)
dear["Age"].fillna(dear["Age"].mean(), inplace=True)

# %%
dear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    int64
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.0+ KB

# %%
dear.corr()
# Out:
# <ipython-input-30-771952837367>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dear.corr()
#              PassengerId    Pclass       Sex       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.026751 -0.023245 -0.030874  0.003818  0.043080
# Pclass         -0.026751  1.000000 -0.108615 -0.440782  0.001087  0.018721
# Sex            -0.023245 -0.108615  1.000000 -0.000011  0.099943  0.159120
# Age            -0.030874 -0.440782 -0.000011  1.000000 -0.079535 -0.045073
# SibSp           0.003818  0.001087  0.099943 -0.079535  1.000000  0.306895
# Parch           0.043080  0.018721  0.159120 -0.045073  0.306895  1.000000
# Fare            0.008211 -0.577147  0.191514  0.329071  0.171539  0.230046
#
#                  Fare
# PassengerId  0.008211
# Pclass      -0.577147
# Sex          0.191514
# ...

# %%
dear.describe()
# Out:
#        PassengerId      Pclass         Sex         Age       SibSp  \
# count   418.000000  418.000000  418.000000  418.000000  418.000000
# mean   1100.500000    2.265550    0.363636   30.272590    0.447368
# std     120.810458    0.841838    0.481622   12.634534    0.896760
# min     892.000000    1.000000    0.000000    0.170000    0.000000
# 25%     996.250000    1.000000    0.000000   23.000000    0.000000
# 50%    1100.500000    3.000000    0.000000   30.272590    0.000000
# 75%    1204.750000    3.000000    1.000000   35.750000    1.000000
# max    1309.000000    3.000000    1.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
dear.plot()
# Out:
# <Axes: >

# %%
dear.describe().plot()
# Out:
# <Axes: >

# %%
sns.regplot(x="Fare", y="Pclass", data=dear)
# Out:
# <Axes: xlabel='Fare', ylabel='Pclass'>

# %% [markdown]
# # Part 2: Decision Tree Classification

# %% [markdown]
# **Part 1: Create a Decision Tree Classifier**

# %%
#Code cell 1
#import pandas
import pandas as pd

#create a pandas dataframe called "training" from the titanic-train.csv file
training = pd.read_csv("/content/drive/MyDrive/Emtech_Drive/titanic_train.csv")

# %%
#Code cell 2
#verify the contents of the training dataframe using the pandas info() method.
#training.?
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **Are there missing values in the data set?**
#
# - Yes, there are actually some values missing with regard to the dataset's contents.

# %%
#Code cell 3
#view the first few rows of the data
#
training.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S

# %%
#Code cell 4

training["Sex"] = training["Sex"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
#Code cell 5
#view the first few rows of the data again
training.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S

# %%
#Code cell 6

training["Age"].fillna(training["Age"].mean(), inplace=True)

# %%
#Code cell 7
#verify that the missing values for the age variable have been eliminated
training["Age"].head(10)
# Out:
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# 5    29.699118
# 6    54.000000
# 7     2.000000
# 8    27.000000
# 9    14.000000
# Name: Age, dtype: float64

# %% [markdown]
# **What is the value that was used to replce the missing ages?**
# - To replace the missing ages, we applied the mean().

# %%
#Code cell 8
#create the array for the target values
y_target = training["Survived"].values

# %%
#Code cell 9
columns = ["Fare", "Pclass", "Sex", "Age", "SibSp"]

#create the variable to hold the features that the classifier will use
X_input = training[list(columns)].values

# %%
#Code cell 10
#import the tree module from the sklearn library
from sklearn import tree

#create clf_train as a decision tree classifier object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

#train the model using the fit() method of the descusion tree object.
#Supply the method with the input variable X_input and the target variable y_target
clf_train = clf_train.fit(X_input, y_target)

# %%
#Code cell 11
clf_train.score(X_input, y_target)
# Out:
# 0.8226711560044894

# %%
#Code cell 12
import six
from sklearn.tree import export_graphviz
with open("titanic.dot", 'w') as f:
  f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns)

# %%
# !apt-get install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
#Code cell 13
#run the Graphviz dot command to convert the .dot file .png
# !dot -Tpng titanic.dot -o titanic.png

# %%
#Code cell 14
#import the Image module from the Ipython.display library
from IPython.display import Image

#display the decision tree graphic
Image("titanic.png")

# %% [markdown]
# **What describes the group that had the most deaths by number? Which group had the most survivors?**
# -

# %% [markdown]
# **Part 2: Apply the Decision Tree Model**

# %%
#Code cell 15
#import the file into the 'testing' dataframe.
testing = pd.read_csv("/content/drive/MyDrive/Emtech_Drive/titanic_test.csv")

testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# **How many recors are in the dataset?**
# - 418 entries in the dataset
#
# **Which import variable(s) are missing values and how many are missing?**
# - The age has 86 missing entries and only 1 in fare

# %%
#Code cell 16
#replace the Gender labels in the testing dataframe
# Hint: look at code cell 4
testing["Sex"] = testing["Sex"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
#Code cell 17
#Use the fillna method of the testing dataframe column "Age"
#to replace missing values with the mean of the age values.
testing["Age"].fillna(testing["Age"].mean(), inplace=True)
testing["Cabin"].fillna("Na", inplace=True)
testing["Fare"].fillna(testing["Fare"].mean(), inplace=True)

# %%
#Code cell 18
#verify the data preparation steps. Enter and run both the info and head
#methods from here by, entering and running one and then the other

testing
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    0
# 3            895       3                              Wirz, Mr. Albert    0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    1
# 415         1307       3                  Saether, Mr. Simon Sivertsen    0
# 416         1308       3                           Ware, Mr. Frederick    0
# 417         1309       3                      Peter, Master. Michael J    0
#
# ...

# %%
testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    int64
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Cabin        418 non-null    object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.0+ KB

# %%
#Code cell 19
#create the variable X_input to hold the features that the classifier will use

X_input = testing[list(columns)].values

# %%
#Code cell 20
#apply the model to the testing data and store the result in a pandas dataframe.
#Use X_input as the argurment for the predict() method of the clf_train classifier object

target_labels = clf_train.predict(X_input)

#convert the target array into a pandas dataframe using the pd.DataFrame() method and target as argume
target_labels = pd.DataFrame({'Est_Survival':target_labels, 'Name':testing['Name']})
#display the first few rows of the data set

# %%
#Code cell 21
#import the numpy library as np
import numpy as np
# Load data for all passengers in the variable all_data
all_data = pd.read_csv("/content/drive/MyDrive/Emtech_Drive/titanic_all.csv")
# Merging using the field Name as key, selects only the rows of the two datasets that refer to the same passenger
testing_results = pd.merge(target_labels, all_data[['Name','Survived']], on=['Name'])

# Compute the accuracy as a ratio of matching observations to total osbervations. Store this in in the variable acc.
acc = np.sum(testing_results['Est_Survival'] == testing_results['Survived']) / float(len(testing_results))
# Print the result
print("Accuracy", acc)
# Out:
# Accuracy 0.7682619647355163

# %%
#code cell 22
#import the titanic_all.csv file into a dataframe called all_data. Specify the list of columns to import.
all_data = pd.read_csv("/content/drive/MyDrive/Emtech_Drive/titanic_all.csv", usecols=['Survived','Pclass', 'Sex','Age','SibSp','Fare'])
#View info for the new dataframe
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1308 non-null   int64
#  1   Pclass    1308 non-null   int64
#  2   Sex       1308 non-null   object
#  3   Age       1045 non-null   float64
#  4   SibSp     1308 non-null   int64
#  5   Fare      1308 non-null   float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 61.4+ KB

# %% [markdown]
# How many record are in the dataset?
# - 1308 entries in the dataframe.
#
# Which important variable(s) are missing values and how many are missing?
# - 263 missing entries in age.

# %%
#Code cell 23
#Label the gender variable with 0 and 1
all_data["Sex"] = all_data["Sex"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
#Code cell 24
#replace missing Age values with the mean age
#display the first few rows of the data set
all_data["Age"].fillna(all_data["Age"].mean(), inplace=True)
all_data.head(5)
# Out:
#    Survived  Pclass  Sex      Age  SibSp      Fare
# 0         1       1    1  29.0000      0  211.3375
# 1         1       1    0   0.9167      1  151.5500
# 2         0       1    1   2.0000      1  151.5500
# 3         0       1    0  30.0000      1  151.5500
# 4         0       1    1  25.0000      1  151.5500

# %%
#Code cell 25
#Import train_test_split() from the sklearn.model_selection libary
from sklearn.model_selection import train_test_split
#create the input and target variables as uppercase X and lowercase y. Reuse the columns variable.
X = all_data[list(columns)].values
y = all_data["Survived"].values

#generate the four testing and training data arrays with the train_test_split() method
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.40, random_state=0)

# %%
#Code cell 26
#create the training decision tree object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

#fit the training model using the input and target variables
clf_train = clf_train.fit(X_train, y_train)

# %%
#Code cell 27
#score the model on the two datasets and store the scores in variables. Convert the scores to strings
train_score = str(clf_train.score(X_train,y_train))
test_score = str(clf_train.score(X_test,y_test))

#output the values in a test string
print('Training score = '+ train_score+' Testing score = '+test_score)
# Out:
# Training score = 0.8201530612244898 Testing score = 0.8053435114503816

# %% [markdown]
# # Conclusion

# %% [markdown]
# **Summary **
# -We showed how to clean and present data for the Titanic dataframe. Additionally, we showcased decision tree classification using the dataframe.
#
# **Conclusion**
# - In conclusion, data analysis can present data in a much more accurate and organized way by utilizing cutting-edge techniques like data tree classification and linear regression.
#
# **Lessons Learned**
# - In order to widen my understanding of data analysis, I also learned how to perform data tree classification and linear regression in addition to learning the fundamentals of plotting.
