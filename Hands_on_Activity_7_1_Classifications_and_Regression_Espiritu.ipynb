# %% [markdown]
# **Hands-on Activity 7.1 : Classifications and Regression**
#
# Name: **Espiritu, Diego Angelo G.**
#
# Course and Section: **CPE019 - CPE32S1**
#
# Instructor: **Engr. Roman Richard**
#
# Date: **06/30/2024**

# %% [markdown]
# 1. Choose any dataset applicable to the classification problem, and also, choose any dataset applicable to the regression problem.
# 2. Explain your datasets and the problem being addressed.
# 3. For classification, do the following:
#   1. Create a base model
#   2. Evaluate the model with k-fold cross validation
#   3. Improve the accuracy of your model by applying additional hidden layers
# 4. For regression, do the following:
#   1. Create a base model
#   2. Improve the model by standardizing the dataset
#   3. Show tuning of layers and neurons (see evaluating small and larger networks)
# 5. Submit the link to your Google Colab (make sure that it is accessible to me)

# %%
import pandas as pd
import numpy as np

housingDF = pd.read_csv("/content/drive/MyDrive/CPE019/Housing.csv") #Regression type dataset
appleDF = pd.read_csv("/content/drive/MyDrive/CPE019/apple_quality.csv") #Classification type dataset

# %%
appleDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   int64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   float64
#  8   Quality      4000 non-null   object
# dtypes: float64(7), int64(1), object(1)
# memory usage: 281.4+ KB

# %% [markdown]
# The Apple Quality dataset is the classification dataset that was used where classifiers more especially, binary classifiers are the target variable and the quality variable is limited to two labels good and bad. Developing a model for binary classification data types based on the input variables included in the dataset is the challenge with this dataset.

# %%
housingDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# The Housing Prices dataset is the one used for regression analysis. wherein continuous data more especially, the price itself is the target variable. Finding and developing a model for regression type data based on the input variables included in the dataset is the challenge with this dataset.

# %% [markdown]
# # Classification Problem

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
# Size: Size of the fruit
# Weight: Weight of the fruit
# Sweetness: Degree of sweetness of the fruit
# Crunchiness: Texture indicating the crunchiness of the fruit
# Juiciness: Level of juiciness of the fruit
# Ripeness: Stage of ripeness of the fruit
# Acidity: Acidity level of the fruit
# Quality: Overall quality of the fruit
columns = ["Size", "Weight", "Sweetness", "Crunchiness", "Juiciness", "Ripeness", "Acidity"]
apple_x = appleDF[list(columns)].values
apple_y = appleDF["Quality"].values

# %%
# encode class values as integers
seed = 7
np.random.seed(seed)
encoder = LabelEncoder()
encoder.fit(apple_y)
encoded_Y = encoder.transform(apple_y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = to_categorical(encoded_Y)

# %%
# define baseline model
def baseline_model():
  # create model
  model = Sequential()
  model.add(Dense(60, input_shape = (len(columns),), activation= 'relu' ))
  model.add(Dense(1, activation= 'sigmoid' ))
  # Compile model
  model.compile(loss= 'binary_crossentropy' , optimizer= 'adam' , metrics=[ 'accuracy' ])
  return model

# %%
# Evaluate The Model with k-Fold Cross Validation
estimator = KerasClassifier(model=baseline_model, epochs=100, batch_size=5, verbose = 1)
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(estimator, apple_x, dummy_y, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5027 - loss: 0.7967
# Epoch 2/100
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6851 - loss: 0.6174
# Epoch 3/100
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7705 - loss: 0.5223
# Epoch 4/100
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7870 - loss: 0.4853
# Epoch 5/100
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8106 - loss: 0.4516
# Epoch 6/100
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8146 - loss: 0.4289
# Epoch 7/100
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8096 - loss: 0.4289
# Epoch 8/100
# ...

# %% [markdown]
# With a standard deviation of 2.01%, the accuracy of the baseline model is 83.42%. The model has been run ten times, and the KFold validation has assessed the outcomes of those ten runs. The model was trained for 20 minutes before finishing, and while its accuracy score of 83.42% may seem impressive, it appears to perform worse than neural networks when compared to other examples.

# %%
# Improve the accuracy of your model by applying additional hidden layers
# define baseline model
def model_2():
  # create model
  model = Sequential()
  model.add(Dense(60, input_dim = len(columns), activation= 'relu' ))
  model.add(Dense(120, activation = 'relu'))
  model.add(Dense(2, activation= 'sigmoid' ))
  # Compile model
  model.compile(loss= 'binary_crossentropy' , optimizer= 'adam' , metrics=[ 'accuracy' ])
  return model

# %%
# Evaluate The Model with k-Fold Cross Validation
estimator = KerasClassifier(model=model_2, epochs=20, batch_size=5, verbose = 1)
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(estimator, apple_x, dummy_y, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7861 - loss: 0.4616
# Epoch 2/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8749 - loss: 0.3000
# Epoch 3/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8931 - loss: 0.2516
# Epoch 4/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9111 - loss: 0.2350
# Epoch 5/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9148 - loss: 0.2221
# Epoch 6/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9172 - loss: 0.2061
# Epoch 7/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9254 - loss: 0.1829
# Epoch 8/20
# ...

# %% [markdown]
# By using extra hidden layers one layer with 120 nodes, specifically and fewer epochs per fold specifically, 20 instead of 100 the accuracy of the second model increases from the baseline 83.42% by 10% to **93.60%** accuracy with a low standard deviation of 1.41%

# %%
# Improve the accuracy of your model by applying additional hidden layers
# define baseline model
def model_3():
  # create model
  model = Sequential()
  model.add(Dense(60, input_dim = len(columns), activation= 'relu' ))
  model.add(Dense(120, activation = 'relu'))
  model.add(Dense(120, activation = 'relu'))
  model.add(Dense(2, activation= 'sigmoid' ))
  # Compile model
  model.compile(loss= 'binary_crossentropy' , optimizer= 'adam' , metrics=[ 'accuracy' ])
  return model

# %%
# Evaluate The Model with k-Fold Cross Validation with standardization
from sklearn.preprocessing import StandardScaler
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(model=model_3, epochs=20, batch_size=5, verbose = 1)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(estimator, apple_x, dummy_y, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7782 - loss: 0.4500
# Epoch 2/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8845 - loss: 0.2726
# Epoch 3/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9046 - loss: 0.2348
# Epoch 4/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9052 - loss: 0.2280
# Epoch 5/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9156 - loss: 0.2033
# Epoch 6/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9225 - loss: 0.1900
# Epoch 7/20
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9296 - loss: 0.1750
# Epoch 8/20
# ...

# %% [markdown]
# The accuracy of the second model in comparison to the first is instead poor, coming in at **93.83%** with 0.99% standard deviation after an additional hidden layer of 1 layer with 120 neurons, for a total of 2 hidden layers. Standardization was applied by using a standard scaler for our dataset. This represents only a 0.23% increase over the results of the first model. This suggests that simply adding more hidden layers to the model does not ensure improved performance; while it performs well, there isn't much of a performance difference between the modifications.

# %% [markdown]
# # Regression Problem

# %%
import numpy
import pandas
from keras.models import Sequential
from keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
columns = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
           'waterfront', 'view', 'condition', 'grade', 'sqft_above',
           'sqft_basement', 'sqft_living15', 'sqft_lot15']
house_x = housingDF[list(columns)].astype('object').values
house_y = housingDF["price"].astype('object').values

# %%
# define base mode
def baseline_model():
  # create model
  model = Sequential()
  model.add(Dense(18, input_shape=(len(columns),), kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(1, kernel_initializer='normal'))
  # Compile model
  model.compile(loss= 'mean_squared_error' , optimizer= 'adam')
  return model

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=baseline_model, epochs=10, batch_size=10, verbose=1)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, house_x, house_y, cv=kfold, scoring='neg_mean_squared_error')
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 244846034944.0000
# Epoch 2/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 131561922560.0000
# Epoch 3/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 106988339200.0000
# Epoch 4/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 98966290432.0000
# Epoch 5/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 89014083584.0000
# ...

# %% [markdown]
# I have used the housing regressional type dataset for the initial model. I obtain a wildly incomprehensible Mean Squared Error of about -60 billion using a base layer of 18 and a single output layer, with little to no preprocessing or standardization. This could be caused by either the dataset itself or the lack of data preparation.

# %%
def model_2():
  model = Sequential()
  model.add(Dense(60, input_shape=(len(columns),), kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(200, kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(300, kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(1, kernel_initializer='normal'))
  model.compile(loss= 'mean_squared_error' , optimizer= 'adam')
  return model
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=model_2, epochs=10, batch_size=10, verbose=1)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10)
results = cross_val_score(pipeline, house_x, house_y, cv=kfold, scoring='neg_mean_squared_error')
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 224528318464.0000
# Epoch 2/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 52706959360.0000
# Epoch 3/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 48041660416.0000
# Epoch 4/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 49080061952.0000
# Epoch 5/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 44591718400.0000
# ...

# %% [markdown]
# The second model has two additional hidden layers with 200 and 400 nodes each, in addition to standardization. The resulting MSE is still in the billions, but it varies by 22 billion from the first model. While this may seem significant, there is still a long way to go before the model can even be considered to perform well.

# %%
# Normalize X values
from sklearn import preprocessing as prep
min_max_scaler = prep.MinMaxScaler()
house_x = min_max_scaler.fit_transform(house_x)

# %%
house_x
# Out:
# array([[0.06060606, 0.125     , 0.06716981, ..., 0.        , 0.16193426,
#         0.00574235],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.08298755, 0.22216486,
#         0.00802712],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.        , 0.3994149 ,
#         0.00851302],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.        , 0.10686629,
#         0.00155764],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.        , 0.17398038,
#         0.00073057],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.        , 0.10686629,
#         0.00081098]])

# %%
def model_3():
  model = Sequential()
  model.add(Dense(60, input_shape=(len(columns),), kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(512, kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(1024, kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(1024, kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(1024, kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(512, kernel_initializer='normal', activation= 'relu'))
  model.add(Dense(1, kernel_initializer='normal'))
  model.compile(loss= 'mean_squared_error' , optimizer= 'adam')
  return model
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=model_3, epochs=10, batch_size=10, verbose=1)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10)
results = cross_val_score(pipeline, house_x, house_y, cv=kfold, scoring='neg_mean_squared_error')
print("Model 3: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 79457222656.0000
# Epoch 2/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 44547874816.0000
# Epoch 3/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 41790558208.0000
# Epoch 4/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 42757201920.0000
# Epoch 5/10
# 1946/1946 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 43046768640.0000
# ...

# %%
print("Model 1: %.3f (%.3f) RMSE" % (np.sqrt(66210922141.56), np.sqrt((8581226588.35))))
print("Model 2: %.3f (%.3f) RMSE" % (np.sqrt(43613200234.26), np.sqrt((3491511238.88))))
print("Model 3: %.3f (%.3f) RMSE" % (np.sqrt(-(results.mean())), np.sqrt((results.std()))))
# Out:
# Model 1: 257314.831 (92634.910) RMSE
# Model 2: 208837.737 (59089.011) RMSE
# Model 3: 200589.259 (65281.988) RMSE

# %% [markdown]
# The evaluation results are easier to understand when the root mean squared error is used instead of our MSE, which has billions. Based on our interpretation of the data, the model's predicted values differ by approximately 200k from the corresponding actual values, indicating that they are far from perfect. On the other hand, Model 2 employs standardization and has a larger network, while Model 3 uses the input data that has been normalized before it is standardized and has an even larger network. Model 1 is our baseline model, with a base amount of layers and little to no preprocessing. It is evident that there is a significant difference in the error score between Models 1 and 2, but not between Models 2 and 3.
